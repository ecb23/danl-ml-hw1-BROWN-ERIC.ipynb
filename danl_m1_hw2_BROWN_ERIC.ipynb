# %% [markdown]
# <a href="https://colab.research.google.com/github/ecb23/danl-ml-hw1-BROWN-ERIC.ipynb/blob/main/danl_m1_hw2_BROWN_ERIC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

nhl = pd.read_csv('https://bcdanl.github.io/data/NHL-1617.csv')
nhl
# Out:
#      id_player        Born            City Cntry  Nat  Ht   Wt    Last_Name  \
# 0            1  30.04.1988        Hamilton   CAN  CAN  69  170       Abbott
# 1            2  25.02.1987        Muskegon   USA  USA  74  218   Abdelkader
# 2            3  23.09.1993       Stockholm   SWE  SWE  71  196        Aberg
# 3            4  01.12.1991        Johnston   USA  USA  70  208      Acciari
# 4            5  30.04.1992      Morristown   USA  USA  72  202     Agostino
# ..         ...         ...             ...   ...  ...  ..  ...          ...
# 883        884  18.04.1993        Huddinge   SWE  SWE  74  215    Zibanejad
# 884        885  01.09.1987         Toronto   CAN  CAN  71  180  Zolnierczyk
# 885        886  01.09.1987            Oslo   NOR  NOR  67  179   Zuccarello
# 886        887  16.01.1992   Newport Beach   USA  USA  71  187       Zucker
# 887        888  15.05.1995  St. Petersburg   RUS  RUS  73  224        Zykov
#
#     First_Name Position Team  GP   G   A    TOI  TOI_GP
# ...

# %%
import pandas as pd
nhl = pd.read_csv("https://bcdanl.github.io/data/NHL-1617.csv")

# %%
#Question 1: How many players had at least some ice time?

nhl = pd.read_csv('https://bcdanl.github.io/data/NHL-1617.csv')
nhl

nhl.count()

nhl['TOI']

#Answer=374 players
# 888(total)-514(0min icetime)= 374

nhl[['TOI']].count()
#^ still shows the '0' toi values...??
# Out:
# TOI    888
# dtype: int64

# %%
nhl.dtypes
# Out:
# id_player       int64
# Born           object
# City           object
# Cntry          object
# Nat            object
# Ht              int64
# Wt              int64
# Last_Name      object
# First_Name     object
# Position       object
# Team           object
# GP              int64
# G               int64
# A               int64
# TOI             int64
# TOI_GP        float64
# dtype: object

# %%
#Question 2: Who is the top scorer?

nhl

nhl.sort_values(["G"])


#ANSWER- Most Goals= Sidney Crosby
# Out:
#      id_player        Born          City Cntry  Nat  Ht   Wt  Last_Name  \
# 0            1  30.04.1988      Hamilton   CAN  CAN  69  170     Abbott
# 523        524  10.12.1992    Plantation   USA  USA  78  225      Megna
# 520        521  22.02.1993       Langley   CAN  CAN  74  214    McNeill
# 512        513  22.05.1994      Hamilton   CAN  CAN  74  203    McEneny
# 508        509  05.08.1995       Anaheim   USA  USA  75  217   McCoshen
# ..         ...         ...           ...   ...  ...  ..  ...        ...
# 802        803  13.12.1991     Yaroslavl   RUS  RUS  72  219  Tarasenko
# 485        486  11.05.1988       Halifax   CAN  CAN  69  181   Marchand
# 426        427  17.06.1993        Maykop   RUS  RUS  71  178   Kucherov
# 499        500  17.09.1997    Scottsdale   USA  USA  75  216   Matthews
# 149        150  07.08.1987  Cole Harbour   CAN  CAN  71  200     Crosby
#
#     First_Name Position Team  GP   G   A    TOI  TOI_GP
# ...

# %%
#Question 3: How can we count the number of NHL players in each country?

#we use value counts command

nhl['Cntry'].value_counts()
# Out:
# CAN    415
# USA    242
# SWE     77
# RUS     39
# CZE     31
# FIN     30
# CHE     12
# SVK     10
# DNK      9
# DEU      6
# AUT      5
# FRA      4
# NOR      2
# LVA      1
# EST      1
# SVN      1
# GBR      1
# HRV      1
# ITA      1
# Name: Cntry, dtype: int64

# %%
#Question 4: How many unique countries are in nhl.csv?

#. count shows us amount of unique values


nhl['Cntry'].value_counts()

#ANSWER = 19 COUNTRIES
# Out:
# CAN    415
# USA    242
# SWE     77
# RUS     39
# CZE     31
# FIN     30
# CHE     12
# SVK     10
# DNK      9
# DEU      6
# AUT      5
# FRA      4
# NOR      2
# LVA      1
# EST      1
# SVN      1
# GBR      1
# HRV      1
# ITA      1
# Name: Cntry, dtype: int64

# %%
#Question 5: WHich three nationalities have the highest number of players?


#answer= Canada, USA< and Sweden have most players
